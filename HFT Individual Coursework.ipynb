# %%
import pandas as pd # for loading pandas data

import scipy.io as sio  # for loading matlab data

import numpy as np      # for numerical libs

from matplotlib.ticker import FuncFormatter # for custom bar plot labels

import matplotlib.pyplot as plt  # for plotting

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %% [markdown]
# # Load Data

# %%
data = sio.loadmat('AMZN_20141103.mat')

# %%
LOB=data['LOB']

t = (np.array((LOB['EventTime'][0][0][:,0]))-3600000*9.5)*1e-3
bid = np.array(LOB['BuyPrice'][0][0]*1e-4)
bidvol = np.array(LOB['BuyVolume'][0][0]*1.0)
ask = np.array(LOB['SellPrice'][0][0]*1e-4)
askvol = np.array(LOB['SellVolume'][0][0]*1.0)
MO=np.array(LOB['MO'][0][0]*1.0)
dt = t[1]-t[0]

# %% [markdown]
# # Midprice, Microprice, and Spread

# %%
midprice = 0.5*(bid[:,0]+ask[:,0])
microprice= (bid[:,0]*askvol[:,0]+ask[:,0]*bidvol[:,0])/(bidvol[:,0]+askvol[:,0])
spread = ask[:,0]-bid[:,0]

# %%
data = pd.DataFrame(midprice)

# %%
data.describe()
# Out:
#                    0
# count  234000.000000
# mean      306.234948
# std         0.971306
# min       303.265000
# 25%       305.525000
# 50%       306.430000
# 75%       306.980000
# max       307.985000

# %% [markdown]
# Plotting Midprice

# %%
plt.plot(t, midprice)
plt.title('Midprice')
plt.ylabel('price')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %% [markdown]
# Plotting Microprice

# %%
plt.plot(t, microprice)
plt.title('Microprice')
plt.ylabel('price')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %% [markdown]
# Ploting the difference between Midprice and Microprice

# %%
plt.plot(t, microprice-midprice)
plt.title('Microprice - Midprice')
plt.ylabel('diff')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %% [markdown]
# Note:The difference is typically in the range [-0.02, 0.02] while at the beginning of the day it is twice times as large.

# %% [markdown]
# Plotting Spread

# %%
plt.plot(t,spread)
plt.title('Spread')
plt.ylabel('spread')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %% [markdown]
# This plot shows that the spread is about 0.6 in the morning, but drops significantly between 0.4 to 0.45 (Mostly in the morning) otherwise it trails below 0.4.

# %%
plt.hist(spread,bins=[0.01,0.02,0.03], width=0.001,align='mid') 
plt.title("History of spread")
plt.xlabel(r'spread')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# plt.plot(t, midprice)
# plt.title('Midprice')
# plt.ylabel('price')
# plt.xlabel('time (seconds from trading start)')
# plt.show()

# %% [markdown]
# # Volume Imbalance

# %%
rho = np.array((bidvol[:,0]-askvol[:,0])/(bidvol[:,0]+askvol[:,0]),ndmin=2).T

# %%
plt.plot(t, rho)
plt.title('Imbalance')
plt.ylabel(r'$\rho$')
plt.xlabel('time (seconds from trading start)')

a = plt.axes([.65, .6, .2, .2])
idx = (t>3600) & (t<=3600+60)
plt.plot( t[idx], rho[idx])
plt.title('a')
plt.ylabel(r'$\rho$')
plt.xlabel(r'$t$')
plt.xticks([3600,3630,3660])

plt.show()

# %%
plt.acorr(rho[:,0]-np.mean(rho[:,0]),maxlags=6000)  # maximum one minute 
plt.title('Autocorrelation of imbalance')
plt.xlim([0,6000])
plt.show()

# %%
plt.hist(rho, bins=np.linspace(-1, 1, num=50)) 
plt.title("Hist of imbalance")
plt.xlabel(r'$\rho$')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# # Volume Imbalance at times of Market Orders:-

# %%
rho_MO = (MO[:,3]-MO[:,4])/(MO[:,3]+MO[:,4])

# %%
plt.hist(rho_MO[MO[:,7]==-1], bins=np.linspace(-1, 1, num=10),alpha=0.5)
plt.hist(rho_MO[MO[:,7]==+1], bins=np.linspace(-1, 1, num=10),alpha=0.5)
plt.title("Hist of imbalance conditional on MO type")
plt.xlabel(r'$\rho$')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# # Liquidation Permanent Price Impact

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: nbformat in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (5.5.0)
# Requirement already satisfied: IPython in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (7.31.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: decorator in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: backcall in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: appnope in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: pygments in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (63.4.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (4.16.0)
# Requirement already satisfied: jupyter_core in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (4.11.1)
# Requirement already satisfied: fastjsonschema in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jellyjelly/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import import_ipynb
import Liquidation_Permanent_Price_Impact_helper as lppi_helpers
# Out:
# importing Jupyter notebook from Liquidation_Permanent_Price_Impact_helper.ipynb

# %%
T = 1 #Time 
Ndt = 6.5 * 3600
dt = T / Ndt
t = np.arange(0, T + dt, dt)

k = 0.003 #parameter to be set
b = 0.005 #modification can be done

tau = T - t #time left
tt = np.arange(0, 1 + 1 / 10, 1 / 10) 

myphi = np.array([10e-10, 0.001, 0.01, 0.1]) #can do two or three
symb = np.array(["o", "*", "+", "^"])

alpha = 90 #terminal panelty, can change the value

# %%
lppi_helpers.plot_inventory_trading_speed(0.01, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = 0.01$")
lppi_helpers.plot_inventory_trading_speed(100, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = +\infty$")

# %%
# Parameter Settings
a = np.array([1, 0.8, 0.6])
k = 0.0003
b = 0.0005

phi = 10 * k
alpha = 100 * k
T = 1
qmax = 1

Ndt = 10000
Ndq = 100

dt = T / Ndt
dq = qmax / Ndq

# %%
nus, Qs, myleg, t, q = lppi_helpers.solve_pde(T, dt, qmax, dq, k, a, b, alpha, phi, Ndt, Ndq)

# %%
lppi_helpers.plot_multiple(t, nus.T, r"Time", r"Trading Speed $\nu^*_t$", None, myleg)

# %%
lppi_helpers.plot_multiple(t, Qs.T, r"Time", r"Inventory $Q_t^{\nu^*}$", None, myleg)

# %% [markdown]
# # Set up the Parameters:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# parameters
S0 = 100
N = 10 ** 6 #Initial number of stocks
T = 1; 
k = 1e-3;
b = 1e-5
M = 1000;    #Number of trading times
alpha = 0.09; 
phi = 0.01;
sigma = 0.30;

# %% [markdown]
# # Calculate the Rest Parameters:

# %%
gamma = np.sqrt(phi/k);
xi = (alpha - 0.5 * b + np.sqrt(k * phi))/(alpha - 0.5 * b - np.sqrt(k * phi));

# %%
tt = np.linspace(0, 1, M + 1)

# %% [markdown]
# # Optimal Trading Speed and Inventory Process

# %%
v = np.zeros((M + 1, 1))
q = np.zeros((M + 1, 1))
v[0] = 0
q[0] = N  
for t in range(1, M + 1): 
    v[t] = gamma * (xi * np.exp(gamma * (T-tt[t-1])) + np.exp(- gamma * (T-tt[t-1]))) / (xi * np.exp(gamma * (T-tt[t-1])) - np.exp(- gamma * (T-tt[t-1]))) * q[t-1] * T/M
    q[t] = (xi * np.exp(gamma * (T-tt[t-1])) - np.exp(- gamma * (T-tt[t-1]))) / (xi * np.exp(gamma * T) - np.exp(- gamma * T)) * N

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], v[1:], 'b', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Number of Shares')
plt.title('Trading Speed')
# Out:
# Text(0.5, 1.0, 'Trading Speed')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, q, 'b', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Number of Shares')
plt.title('Inventory')
# Out:
# Text(0.5, 1.0, 'Inventory')
